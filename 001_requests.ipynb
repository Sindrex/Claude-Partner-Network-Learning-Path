# %%
# Install deps
# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Using cached anthropic-1.8.0-py3-none-any.whl (1.3 MB)
# Requirement already satisfied: python-dotenv in c:\python310\lib\site-packages (0.19.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\sindre\appdata\roaming\python\python310\site-packages (from anthropic) (4.16.0)
# Collecting pydantic<3,>=1.10.0
#   Using cached pydantic-2.13.5-py3-none-any.whl (472 kB)
# Collecting anyio<5,>=4.1.0
#   Using cached anyio-4.15.1-py3-none-any.whl (132 kB)
# Collecting docstring-parser<1,>=0.15
#   Using cached docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Collecting jiter<1,>=0.4.0
#   Using cached jiter-0.17.0-cp310-cp310-win_amd64.whl (231 kB)
# Collecting httpx2<3,>=2.0.0
#   Using cached httpx2-2.13.1-py3-none-any.whl (95 kB)
# Collecting sniffio<2,>=1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sindre\appdata\roaming\python\python310\site-packages (from anyio<5,>=4.1.0->anthropic) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\python310\lib\site-packages (from anyio<5,>=4.1.0->anthropic) (3.20)
# Requirement already satisfied: truststore>=0.10 in c:\python310\lib\site-packages (from httpx2<3,>=2.0.0->anthropic) (0.10.4)
# Collecting httpcore2==2.13.1
#   Using cached httpcore2-2.13.1-py3-none-any.whl (83 kB)
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting pydantic-core==2.46.5
#   Using cached pydantic_core-2.46.5-cp310-cp310-win_amd64.whl (2.0 MB)
# Collecting typing-inspection>=0.4.2
#   Using cached typing_inspection-0.4.4-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.8.0-py3-none-any.whl (13 kB)
# Installing collected packages: h11, typing-inspection, pydantic-core, httpcore2, anyio, annotated-types, sniffio, pydantic, jiter, httpx2, docstring-parser, anthropic
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] Systemet finner ikke angitt fil: 'c:\\Python310\\Scripts\\httpx2.exe' -> 'c:\\Python310\\Scripts\\httpx2.exe.deleteme'
#
# WARNING: You are using pip version 21.2.3; however, version 26.2.1 is available.
# You should consider upgrading via the 'c:\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# create an api client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 # create an api client
# ----> 2 from anthropic import Anthropic
#       4 client = Anthropic()
#       5 model = "claude-sonnet-4-0"
#
# ModuleNotFoundError: No module named 'anthropic'
